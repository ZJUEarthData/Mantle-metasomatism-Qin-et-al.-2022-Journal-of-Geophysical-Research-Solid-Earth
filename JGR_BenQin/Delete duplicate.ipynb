# %% [markdown]
# # major elements duplicate drop

# %%
import pandas as pd 
import numpy as np

# %%
#data1=pd.read_excel("599 1x1 test.xlsx")
df1=pd.read_excel("D:\\合作Papers\\2021 秦奔 JGR\\稿件\\Supplements\\Zenodo.org\\Dataset\\Parent dataset.xlsx",sheet_name= 'Trace elements')

# %%
df1
# Out:
#                            CITATIONS       SAMPLE NAME      TECTONIC SETTING  \
# 0     [10168] ZHENG JIAN-PING (2001)     samp. HB92047  INTRAPLATE VOLCANICS
# 1     [10168] ZHENG JIAN-PING (2001)        samp. HB12  INTRAPLATE VOLCANICS
# 2     [10168] ZHENG JIAN-PING (2001)        samp. HB22  INTRAPLATE VOLCANICS
# 3     [10168] ZHENG JIAN-PING (2001)     samp. HB92045  INTRAPLATE VOLCANICS
# 4     [10168] ZHENG JIAN-PING (2001)        samp. HB6A  INTRAPLATE VOLCANICS
# ...                              ...               ...                   ...
# 2962         [9699] KAESER B. (2006)  samp. KE 1958/13        RIFT VOLCANICS
# 2963         [9699] KAESER B. (2006)  samp. KE 1958/13        RIFT VOLCANICS
# 2964         [9699] KAESER B. (2006)  samp. KE 1958/13        RIFT VOLCANICS
# 2965         [9699] KAESER B. (2006)  samp. KE 1959/25        RIFT VOLCANICS
# 2966         [9699] KAESER B. (2006)  samp. KE 1959/25        RIFT VOLCANICS
#
# ...

# %%
df2=df1.drop_duplicates(subset=['SAMPLE NAME'],keep='last',inplace=False)

# %%
df2
# Out:
#                            CITATIONS       SAMPLE NAME      TECTONIC SETTING  \
# 0     [10168] ZHENG JIAN-PING (2001)     samp. HB92047  INTRAPLATE VOLCANICS
# 1     [10168] ZHENG JIAN-PING (2001)        samp. HB12  INTRAPLATE VOLCANICS
# 2     [10168] ZHENG JIAN-PING (2001)        samp. HB22  INTRAPLATE VOLCANICS
# 3     [10168] ZHENG JIAN-PING (2001)     samp. HB92045  INTRAPLATE VOLCANICS
# 4     [10168] ZHENG JIAN-PING (2001)        samp. HB6A  INTRAPLATE VOLCANICS
# ...                              ...               ...                   ...
# 2949         [9699] KAESER B. (2006)   samp. KE 1961/1        RIFT VOLCANICS
# 2956         [9699] KAESER B. (2006)   samp. KE 196181        RIFT VOLCANICS
# 2961         [9699] KAESER B. (2006)   samp. KE 1963/2        RIFT VOLCANICS
# 2964         [9699] KAESER B. (2006)  samp. KE 1958/13        RIFT VOLCANICS
# 2966         [9699] KAESER B. (2006)  samp. KE 1959/25        RIFT VOLCANICS
#
# ...

# %%
data=pd.concat([df1,df2]).drop_duplicates(keep=False)

# %%
data.to_excel("C:\\Users\\lenovo\\Desktop\\result.xlsx")

# %%
data2
# Out:
#          Lon   Lat   Moho    LAB   50km  100km  150km  200km  250km  300km
# 0     -179.5 -89.5  36.15  240.4  4.394  4.558  4.598  4.592  4.665  4.716
# 1     -179.5 -88.5  37.91  209.4  4.400  4.502  4.550  4.565  4.653  4.712
# 2     -179.5 -87.5  39.95  115.7  4.401  4.426  4.482  4.526  4.634  4.705
# 3     -179.5 -86.5  43.11   89.1  4.392  4.384  4.443  4.500  4.620  4.699
# 4     -179.5 -85.5  41.48   62.6  4.378  4.337  4.399  4.471  4.603  4.691
# ...      ...   ...    ...    ...    ...    ...    ...    ...    ...    ...
# 64795  179.5  85.5  22.21  100.0  4.489  4.420  4.301  4.308  4.495  4.644
# 64796  179.5  86.5  19.10   97.8  4.477  4.394  4.284  4.301  4.491  4.641
# 64797  179.5  87.5  17.00  109.7  4.466  4.361  4.260  4.291  4.487  4.638
# 64798  179.5  88.5  15.93  117.7  4.453  4.328  4.244  4.289  4.489  4.641
# 64799  179.5  89.5  16.23   63.9  4.441  4.307  4.240  4.297  4.499  4.648
#
# [64195 rows x 10 columns]

# %%
data2.to_excel("C:\\Users\\lenovo\\Desktop\\test.xlsx")

# %%
#data3=data2.drop_duplicates(subset=['SAMPLE NAME','SIO2(WT%)','TIO2(WT%)','CR2O3(WT%)','FEOT(WT%)','CAO(WT%)','MGO(WT%)','MNO(WT%)','NA2O(WT%)'],keep='first',inplace=False)

# %%
data3
# Out:
#       数据质量  \
# 0        0
# 1        0
# 2        0
# 3        A
# 4        A
# ...    ...
# 22132    A
# 22133    A
# 22134    A
# 22135    A
# 22136    A
#
#       岩相学（1.carbonate  2. apatite  3.amphibole   4.phlogopite  5.glass  6.silicate melt inclusion 7.古老克拉通未被交代）  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 22132                                                NaN
# 22133                                                NaN
# 22134                                                NaN
# 22135                                                NaN
# 22136                                                NaN
#
# ...

# %%
data2.to_excel('微量2.xlsx')

# %% [markdown]
# # trace elements drop duplicated data

# %%
import pandas as pd 
import numpy as np

# %%
data4=pd.read_excel("C:\\Users\\lenovo\\Desktop\\地幔岩石cpx微量.xlsx")

# %%
data4
# Out:
#      数据质量  \
# 0       A
# 1       A
# 2       A
# 3       A
# 4       A
# ...   ...
# 2982    A
# 2983    A
# 2984    A
# 2985    A
# 2986    A
#
#      岩相学（1.carbonate  2. apatite  3.amphibole   4.phlogopite  5.glass  6.Silicate melt 7.古老克拉通未被交代）  \
# 0                                                   NaN
# 1                                                     3
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2982                                                  5
# 2983                                                  5
# 2984                                                  5
# 2985                                                  5
# 2986                                                  5
#
#      Note（inclusion、pocket、vein）   是否交代                        CITATION  \
# ...

# %%
data5=data4.drop_duplicates(subset=None,keep='first',inplace=False)

# %%
data5
# Out:
#      数据质量  \
# 0       A
# 1       A
# 2       A
# 3       A
# 4       A
# ...   ...
# 2982    A
# 2983    A
# 2984    A
# 2985    A
# 2986    A
#
#      岩相学（1.carbonate  2. apatite  3.amphibole   4.phlogopite  5.glass  6.Silicate melt 7.古老克拉通未被交代）  \
# 0                                                   NaN
# 1                                                     3
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2982                                                  5
# 2983                                                  5
# 2984                                                  5
# 2985                                                  5
# 2986                                                  5
#
#      Note（inclusion、pocket、vein）   是否交代                        CITATION  \
# ...

# %%
data6=data5.drop_duplicates(subset=['SAMPLE NAME','SC(PPM)','TI(PPM)','V(PPM)','CR(PPM)','NI(PPM)','RB(PPM)','SR(PPM)','Y(PPM)','ZR(PPM)','NB(PPM)','BA(PPM)','LA(PPM)','CE(PPM)','PR(PPM)','ND(PPM)','SM(PPM)','EU(PPM)','GD(PPM)','TB(PPM)','DY(PPM)','HO(PPM)','ER(PPM)','TM(PPM)','YB(PPM)','LU(PPM)','HF(PPM)','TA(PPM)','PB(PPM)','TH(PPM)','U(PPM)'],keep='first',inplace=False)

# %%
data6
# Out:
#      数据质量  \
# 0       A
# 1       A
# 2       A
# 3       A
# 4       A
# ...   ...
# 2982    A
# 2983    A
# 2984    A
# 2985    A
# 2986    A
#
#      岩相学（1.carbonate  2. apatite  3.amphibole   4.phlogopite  5.glass  6.Silicate melt 7.古老克拉通未被交代）  \
# 0                                                   NaN
# 1                                                     3
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2982                                                  5
# 2983                                                  5
# 2984                                                  5
# 2985                                                  5
# 2986                                                  5
#
#      Note（inclusion、pocket、vein）   是否交代                        CITATION  \
# ...

# %%
data6.to_excel('去重微量.xlsx')
